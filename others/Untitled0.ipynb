# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/DNNDK/model_conversion
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/DNNDK/model_conversion

# %%
# %cd ../quantization
# Out:
# 2024-03-15 11:45:19.499920: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-15 11:45:19.500006: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-15 11:45:19.501626: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-15 11:45:20.912963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model: "yolov3_tiny"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, None, None, 3)]      0         []
#
#  yolo_darknet (Functional)   ((None, None, None, 256),    6298480   ['input[0][0]']
#                               (None, None, None, 1024))
#
#  yolo_conv_0 (Functional)    (None, None, None, 256)      263168    ['yolo_darknet[0][1]']
#
#  yolo_conv_1 (Functional)    (None, None, None, 384)      33280     ['yolo_conv_0[0][0]',
#                                                                      'yolo_darknet[0][0]']
#
#  yolo_output_0 (Functional)  (None, None, None, 3, 85)    1312511   ['yolo_conv_0[0][0]']
#
#  yolo_output_1 (Functional)  (None, None, None, 3, 85)    951295    ['yolo_conv_1[0][0]']
#
#  yolo_boxes_0 (Lambda)       ((None, None, None, 3, 4),   0         ['yolo_output_0[0][0]']
#                               (None, None, None, 3, 1),
#                               (None, None, None, 3, 80)
#                              , (None, None, None, 3, 4)
#                              )
#
#  yolo_boxes_1 (Lambda)       ((None, None, None, 3, 4),   0         ['yolo_output_1[0][0]']
#                               (None, None, None, 3, 1),
#                               (None, None, None, 3, 80)
#                              , (None, None, None, 3, 4)
#                              )
#
#  yolo_nms (Lambda)           ((None, 100, 4),             0         ['yolo_boxes_0[0][0]',
#                               (None, 100),                           'yolo_boxes_0[0][1]',
#                               (None, 100),                           'yolo_boxes_0[0][2]',
#                               (None,))                               'yolo_boxes_1[0][0]',
#                                                                      'yolo_boxes_1[0][1]',
#                                                                      'yolo_boxes_1[0][2]']
#
# ==================================================================================================
# Total params: 8858734 (33.79 MB)
# Trainable params: 8852366 (33.77 MB)
# Non-trainable params: 6368 (24.88 KB)
# __________________________________________________________________________________________________
# I0315 11:45:25.801575 136015749021696 convert1.py:24] model created
# I0315 11:45:27.083376 136015749021696 utils.py:46] yolo_darknet/conv2d bn
# /content/drive/MyDrive/DNNDK/model_conversion/convert1.py:26: DeprecationWarning: `product` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `prod` instead.
#   load_darknet_weights(yolo, FLAGS.weights, FLAGS.tiny)
# I0315 11:45:27.100202 136015749021696 utils.py:46] yolo_darknet/conv2d_1 bn
# I0315 11:45:27.110528 136015749021696 utils.py:46] yolo_darknet/conv2d_2 bn
# I0315 11:45:27.116643 136015749021696 utils.py:46] yolo_darknet/conv2d_3 bn
# I0315 11:45:27.772361 136015749021696 utils.py:46] yolo_darknet/conv2d_4 bn
# I0315 11:45:28.262240 136015749021696 utils.py:46] yolo_darknet/conv2d_5 bn
# I0315 11:45:28.306161 136015749021696 utils.py:46] yolo_darknet/conv2d_6 bn
# I0315 11:45:29.011012 136015749021696 utils.py:46] yolo_conv_0/conv2d_7 bn
# I0315 11:45:29.018562 136015749021696 utils.py:46] yolo_output_0/conv2d_8 bn
# I0315 11:45:29.039502 136015749021696 utils.py:46] yolo_output_0/conv2d_9 bias
# I0315 11:45:29.045606 136015749021696 utils.py:46] yolo_conv_1/conv2d_10 bn
# I0315 11:45:29.049361 136015749021696 utils.py:46] yolo_output_1/conv2d_11 bn
# I0315 11:45:29.068442 136015749021696 utils.py:46] yolo_output_1/conv2d_12 bias
# I0315 11:45:29.073758 136015749021696 convert1.py:27] weights loaded
# I0315 11:45:29.449794 136015749021696 convert1.py:31] sanity check passed
# I0315 11:45:29.788205 136015749021696 convert1.py:34] weights saved

# %%
import tensorflow as tf

# 載入.h5模型
model = tf.keras.models.load_model('yolov3.h5')

# 儲存為.pb檔案
tf.saved_model.save(model, 'yolov3.pb')
